# %% [markdown]
# # Embedding techniques using hugging face

# %%
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
load_dotenv # Load all the environment variables

# %%
os.environ['HF_TOKEN']=os.getenv("HF_TOKEN")  # get it from the .env file

# %%
# !pip install sentence_transformers

# %%
# !pip install langchain_huggingface

# %% [markdown]
# # Senetence Transformers on Hugging Face
#
# Hugging face sentence-transformers is a python framework for the stae-of-the-art Sentence, text and image embeddings.
# One of the embedding models is used in the hugging Face Embedding class. We have also added an alias for Sentence Transformer Embedding for Users who  are more familiar with directly using that package.

# %%
from langchain_huggingface import HuggingFaceEmbeddings
HuggingFaceEmbeddings()

# %%
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
text="This is a test documents"
query_result=embeddings.embed_query(text)
query_result
# Out:
# [-0.03786025568842888,
#  0.11697695404291153,
#  -0.035404741764068604,
#  0.04696354642510414,
#  0.030406607314944267,
#  -0.035603463649749756,
#  -0.05769002065062523,
#  0.05563274398446083,
#  -0.024714956060051918,
#  0.040872424840927124,
#  0.0728103518486023,
#  -0.00433765072375536,
#  0.01070591900497675,
#  0.01232137344777584,
#  -0.08437155932188034,
#  -0.0389578603208065,
#  -0.012011954560875893,
#  -0.03701813519001007,
#  0.0032074188347905874,
#  0.07600058615207672,
#  0.03389565646648407,
#  0.07895710319280624,
#  -0.025616370141506195,
#  -0.018020695075392723,
#  0.019124170765280724,
#  0.023785993456840515,
#  -0.0576029047369957,
#  0.012925244867801666,
#  0.07224419713020325,
#  -0.03613686561584473,
#  0.03491003066301346,
#  0.06898690015077591,
#  0.08170377463102341,
#  0.055909544229507446,
#  0.07321041077375412,
#  -0.0015631013084203005,
#  0.06098972260951996,
#  0.02068466879427433,
#  0.03279157727956772,
#  0.025676773861050606,
# ...

# %%
len(query_result)
# Out:
# 384

# %%
doc_result=embeddings.embed_documents([text,"This is not a test document."])

# %%
doc_result[0]
# Out:
# [-0.03786024451255798,
#  0.11697698384523392,
#  -0.0354047529399395,
#  0.046963535249233246,
#  0.03040659986436367,
#  -0.03560340031981468,
#  -0.05769003927707672,
#  0.05563271418213844,
#  -0.024714907631278038,
#  0.040872469544410706,
#  0.07281030714511871,
#  -0.00433760043233633,
#  0.010705907829105854,
#  0.012321283109486103,
#  -0.08437157422304153,
#  -0.03895782306790352,
#  -0.012011983431875706,
#  -0.03701810911297798,
#  0.003207419766113162,
#  0.07600058615207672,
#  0.033895689994096756,
#  0.07895711064338684,
#  -0.025616370141506195,
#  -0.018020668998360634,
#  0.019124113023281097,
#  0.023786015808582306,
#  -0.057602982968091965,
#  0.01292524952441454,
#  0.07224418222904205,
#  -0.03613688424229622,
#  0.03490998223423958,
#  0.0689869150519371,
#  0.08170381933450699,
#  0.05590960383415222,
#  0.07321035116910934,
#  -0.0015630954876542091,
#  0.06098973751068115,
#  0.02068466506898403,
#  0.03279159963130951,
#  0.02567676454782486,
# ...
